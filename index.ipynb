# %% [markdown]
# # Understanding Pandas Series and DataFrames - Lab
#
# ## Introduction
#
# In this lab, let's get some hands-on practice working with data cleanup using Pandas.
#
# ## Objectives
# You will be able to:
#
# - Use the `.map()` and `.apply()` methods to apply a function to a pandas Series or DataFrame
# - Perform operations to change the structure of pandas DataFrames
# - Change the index of a pandas DataFrame
# - Change data types of columns in pandas DataFrames
#
# ## Let's get started!
#
# Import the file `'turnstile_180901.txt'`.

# %%
# Import the required libraries
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Import the file 'turnstile_180901.txt'
df = pd.read_csv('turnstile_180901.txt')

# Print the number of rows ans columns in df
print(df.shape)

# Print the first five rows of df
df.head(0)
df
# Out:
# (197625, 11)
#           C/A  UNIT       SCP        STATION LINENAME DIVISION        DATE  \
# 0        A002  R051  02-00-00          59 ST  NQR456W      BMT  08/25/2018
# 1        A002  R051  02-00-00          59 ST  NQR456W      BMT  08/25/2018
# 2        A002  R051  02-00-00          59 ST  NQR456W      BMT  08/25/2018
# 3        A002  R051  02-00-00          59 ST  NQR456W      BMT  08/25/2018
# 4        A002  R051  02-00-00          59 ST  NQR456W      BMT  08/25/2018
# ...       ...   ...       ...            ...      ...      ...         ...
# 197620  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  08/31/2018
# 197621  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  08/31/2018
# 197622  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  08/31/2018
# 197623  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  08/31/2018
# 197624  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  08/31/2018
#
#             TIME     DESC  ENTRIES  \
# 0       00:00:00  REGULAR  6736067
# 1       04:00:00  REGULAR  6736087
# 2       08:00:00  REGULAR  6736105
# 3       12:00:00  REGULAR  6736180
# 4       16:00:00  REGULAR  6736349
# ...          ...      ...      ...
# 197620  05:00:00  REGULAR     5554
# 197621  09:00:00  REGULAR     5554
# 197622  13:00:00  REGULAR     5554
# 197623  17:00:00  REGULAR     5554
# 197624  21:00:00  REGULAR     5554
#
#         EXITS
# 0                                                 2283184
# 1                                                 2283188
# 2                                                 2283229
# 3                                                 2283314
# 4                                                 2283384
# ...                                                   ...
# 197620                                                348
# 197621                                                348
# 197622                                                348
# 197623                                                348
# 197624                                                348
#
# [197625 rows x 11 columns]

# %% [markdown]
# Rename all the columns to lower case:

# %%
# Rename all the columns to lower case
df.rename(columns = lambda x: x.lower(), inplace=True)
df
# Out:
#           c/a  unit       scp        station linename division        date  \
# 0        A002  R051  02-00-00          59 ST  NQR456W      BMT  08/25/2018
# 1        A002  R051  02-00-00          59 ST  NQR456W      BMT  08/25/2018
# 2        A002  R051  02-00-00          59 ST  NQR456W      BMT  08/25/2018
# 3        A002  R051  02-00-00          59 ST  NQR456W      BMT  08/25/2018
# 4        A002  R051  02-00-00          59 ST  NQR456W      BMT  08/25/2018
# ...       ...   ...       ...            ...      ...      ...         ...
# 197620  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  08/31/2018
# 197621  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  08/31/2018
# 197622  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  08/31/2018
# 197623  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  08/31/2018
# 197624  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  08/31/2018
#
#             time     desc  entries  \
# 0       00:00:00  REGULAR  6736067
# 1       04:00:00  REGULAR  6736087
# 2       08:00:00  REGULAR  6736105
# 3       12:00:00  REGULAR  6736180
# 4       16:00:00  REGULAR  6736349
# ...          ...      ...      ...
# 197620  05:00:00  REGULAR     5554
# 197621  09:00:00  REGULAR     5554
# 197622  13:00:00  REGULAR     5554
# 197623  17:00:00  REGULAR     5554
# 197624  21:00:00  REGULAR     5554
#
#         exits
# 0                                                 2283184
# 1                                                 2283188
# 2                                                 2283229
# 3                                                 2283314
# 4                                                 2283384
# ...                                                   ...
# 197620                                                348
# 197621                                                348
# 197622                                                348
# 197623                                                348
# 197624                                                348
#
# [197625 rows x 11 columns]

# %% [markdown]
# Change the index to `'linename'`:

# %%
# Change the index to 'linename'
df.set_index('linename', inplace=True)
df
# Out:
#             c/a  unit       scp        station division        date      time  \
# linename
# NQR456W    A002  R051  02-00-00          59 ST      BMT  08/25/2018  00:00:00
# NQR456W    A002  R051  02-00-00          59 ST      BMT  08/25/2018  04:00:00
# NQR456W    A002  R051  02-00-00          59 ST      BMT  08/25/2018  08:00:00
# NQR456W    A002  R051  02-00-00          59 ST      BMT  08/25/2018  12:00:00
# NQR456W    A002  R051  02-00-00          59 ST      BMT  08/25/2018  16:00:00
# ...         ...   ...       ...            ...      ...         ...       ...
# R         TRAM2  R469  00-05-01  RIT-ROOSEVELT      RIT  08/31/2018  05:00:00
# R         TRAM2  R469  00-05-01  RIT-ROOSEVELT      RIT  08/31/2018  09:00:00
# R         TRAM2  R469  00-05-01  RIT-ROOSEVELT      RIT  08/31/2018  13:00:00
# R         TRAM2  R469  00-05-01  RIT-ROOSEVELT      RIT  08/31/2018  17:00:00
# R         TRAM2  R469  00-05-01  RIT-ROOSEVELT      RIT  08/31/2018  21:00:00
#
#              desc  entries  \
# linename
# NQR456W   REGULAR  6736067
# NQR456W   REGULAR  6736087
# NQR456W   REGULAR  6736105
# NQR456W   REGULAR  6736180
# NQR456W   REGULAR  6736349
# ...           ...      ...
# R         REGULAR     5554
# R         REGULAR     5554
# R         REGULAR     5554
# R         REGULAR     5554
# R         REGULAR     5554
#
#           exits
# linename
# NQR456W                                             2283184
# NQR456W                                             2283188
# NQR456W                                             2283229
# NQR456W                                             2283314
# NQR456W                                             2283384
# ...                                                     ...
# R                                                       348
# R                                                       348
# R                                                       348
# R                                                       348
# R                                                       348
#
# [197625 rows x 10 columns]

# %% [markdown]
# Reset the index:

# %%
# Reset the index
df.reset_index(inplace=True)
df
# Out:
#          index linename    c/a  unit       scp        station division  \
# 0            0  NQR456W   A002  R051  02-00-00          59 ST      BMT
# 1            1  NQR456W   A002  R051  02-00-00          59 ST      BMT
# 2            2  NQR456W   A002  R051  02-00-00          59 ST      BMT
# 3            3  NQR456W   A002  R051  02-00-00          59 ST      BMT
# 4            4  NQR456W   A002  R051  02-00-00          59 ST      BMT
# ...        ...      ...    ...   ...       ...            ...      ...
# 197620  197620        R  TRAM2  R469  00-05-01  RIT-ROOSEVELT      RIT
# 197621  197621        R  TRAM2  R469  00-05-01  RIT-ROOSEVELT      RIT
# 197622  197622        R  TRAM2  R469  00-05-01  RIT-ROOSEVELT      RIT
# 197623  197623        R  TRAM2  R469  00-05-01  RIT-ROOSEVELT      RIT
# 197624  197624        R  TRAM2  R469  00-05-01  RIT-ROOSEVELT      RIT
#
#               date      time     desc  entries  \
# 0       08/25/2018  00:00:00  REGULAR  6736067
# 1       08/25/2018  04:00:00  REGULAR  6736087
# 2       08/25/2018  08:00:00  REGULAR  6736105
# 3       08/25/2018  12:00:00  REGULAR  6736180
# 4       08/25/2018  16:00:00  REGULAR  6736349
# ...            ...       ...      ...      ...
# 197620  08/31/2018  05:00:00  REGULAR     5554
# 197621  08/31/2018  09:00:00  REGULAR     5554
# 197622  08/31/2018  13:00:00  REGULAR     5554
# 197623  08/31/2018  17:00:00  REGULAR     5554
# 197624  08/31/2018  21:00:00  REGULAR     5554
#
#         exits
# 0                                                 2283184
# 1                                                 2283188
# 2                                                 2283229
# 3                                                 2283314
# 4                                                 2283384
# ...                                                   ...
# 197620                                                348
# 197621                                                348
# 197622                                                348
# 197623                                                348
# 197624                                                348
#
# [197625 rows x 12 columns]

# %% [markdown]
# Create another column `'Num_Lines'` that is a count of how many lines pass through a station. Then sort your DataFrame by this column in descending order.
#
# *Hint: According to the [data dictionary](http://web.mta.info/developers/resources/nyct/turnstile/ts_Field_Description.txt), LINENAME represents all train lines that can be boarded at a given station. Normally lines are represented by one character. For example, LINENAME 456NQR represents trains 4, 5, 6, N, Q, and R.*

# %%
# Add a new 'num_lines' column
df['Num_Lines']= df['linename'].apply(lambda x: len(x))
df
# Out:
#          index linename    c/a  unit       scp        station division  \
# 0            0  NQR456W   A002  R051  02-00-00          59 ST      BMT
# 1            1  NQR456W   A002  R051  02-00-00          59 ST      BMT
# 2            2  NQR456W   A002  R051  02-00-00          59 ST      BMT
# 3            3  NQR456W   A002  R051  02-00-00          59 ST      BMT
# 4            4  NQR456W   A002  R051  02-00-00          59 ST      BMT
# ...        ...      ...    ...   ...       ...            ...      ...
# 197620  197620        R  TRAM2  R469  00-05-01  RIT-ROOSEVELT      RIT
# 197621  197621        R  TRAM2  R469  00-05-01  RIT-ROOSEVELT      RIT
# 197622  197622        R  TRAM2  R469  00-05-01  RIT-ROOSEVELT      RIT
# 197623  197623        R  TRAM2  R469  00-05-01  RIT-ROOSEVELT      RIT
# 197624  197624        R  TRAM2  R469  00-05-01  RIT-ROOSEVELT      RIT
#
#               date      time     desc  entries  \
# 0       08/25/2018  00:00:00  REGULAR  6736067
# 1       08/25/2018  04:00:00  REGULAR  6736087
# 2       08/25/2018  08:00:00  REGULAR  6736105
# 3       08/25/2018  12:00:00  REGULAR  6736180
# 4       08/25/2018  16:00:00  REGULAR  6736349
# ...            ...       ...      ...      ...
# 197620  08/31/2018  05:00:00  REGULAR     5554
# 197621  08/31/2018  09:00:00  REGULAR     5554
# 197622  08/31/2018  13:00:00  REGULAR     5554
# 197623  08/31/2018  17:00:00  REGULAR     5554
# 197624  08/31/2018  21:00:00  REGULAR     5554
#
#         exits                                                                 \
# 0                                                 2283184
# 1                                                 2283188
# 2                                                 2283229
# 3                                                 2283314
# 4                                                 2283384
# ...                                                   ...
# 197620                                                348
# 197621                                                348
# 197622                                                348
# 197623                                                348
# 197624                                                348
#
#         Num_Lines
# 0               7
# 1               7
# 2               7
# 3               7
# 4               7
# ...           ...
# 197620          1
# 197621          1
# 197622          1
# 197623          1
# 197624          1
#
# [197625 rows x 13 columns]

# %% [markdown]
# Write a function to clean column names:

# %%
def clean(col_name):
    # Clean the column name in any way you want to. Hint: think back to str methods 
    cleaned = col_name.strip()
    return cleaned

# %%
# Use the above function to clean the column names
df.rename(columns=clean, inplace=True)
df
# Out:
#          Index Linename    C/a  Unit       Scp        Station Division  \
# 0            0  NQR456W   A002  R051  02-00-00          59 ST      BMT
# 1            1  NQR456W   A002  R051  02-00-00          59 ST      BMT
# 2            2  NQR456W   A002  R051  02-00-00          59 ST      BMT
# 3            3  NQR456W   A002  R051  02-00-00          59 ST      BMT
# 4            4  NQR456W   A002  R051  02-00-00          59 ST      BMT
# ...        ...      ...    ...   ...       ...            ...      ...
# 197620  197620        R  TRAM2  R469  00-05-01  RIT-ROOSEVELT      RIT
# 197621  197621        R  TRAM2  R469  00-05-01  RIT-ROOSEVELT      RIT
# 197622  197622        R  TRAM2  R469  00-05-01  RIT-ROOSEVELT      RIT
# 197623  197623        R  TRAM2  R469  00-05-01  RIT-ROOSEVELT      RIT
# 197624  197624        R  TRAM2  R469  00-05-01  RIT-ROOSEVELT      RIT
#
#              Date      Time     Desc  Entries    Exits  Num_lines day_of_week
# 0      2018-08-25  00:00:00  REGULAR  6736067  2283184          7    Saturday
# 1      2018-08-25  04:00:00  REGULAR  6736087  2283188          7    Saturday
# 2      2018-08-25  08:00:00  REGULAR  6736105  2283229          7    Saturday
# 3      2018-08-25  12:00:00  REGULAR  6736180  2283314          7    Saturday
# 4      2018-08-25  16:00:00  REGULAR  6736349  2283384          7    Saturday
# ...           ...       ...      ...      ...      ...        ...         ...
# 197620 2018-08-31  05:00:00  REGULAR     5554      348          1      Friday
# 197621 2018-08-31  09:00:00  REGULAR     5554      348          1      Friday
# 197622 2018-08-31  13:00:00  REGULAR     5554      348          1      Friday
# 197623 2018-08-31  17:00:00  REGULAR     5554      348          1      Friday
# 197624 2018-08-31  21:00:00  REGULAR     5554      348          1      Friday
#
# [197625 rows x 14 columns]

# %%
# Check to ensure the column names were cleaned
df.columns
# Out:
# Index(['Index', 'Linename', 'C/a', 'Unit', 'Scp', 'Station', 'Division',
#        'Date', 'Time', 'Desc', 'Entries', 'Exits', 'Num_lines', 'day_of_week'],
#       dtype='object')

# %% [markdown]
# - Change the data type of the `'date'` column to a date
# - Add a new column `'day_of_week'` that represents the day of the week

# %%
# Convert the data type of the 'date' column to a date
df['Date'] = pd.to_datetime(df['Date'])

# Add a new column 'day_of_week' that represents the day of the week 
df['day_of_week'] = df['Date'].dt.day_name()
df
# Out:
#          Index Linename    C/a  Unit       Scp        Station Division  \
# 0            0  NQR456W   A002  R051  02-00-00          59 ST      BMT
# 1            1  NQR456W   A002  R051  02-00-00          59 ST      BMT
# 2            2  NQR456W   A002  R051  02-00-00          59 ST      BMT
# 3            3  NQR456W   A002  R051  02-00-00          59 ST      BMT
# 4            4  NQR456W   A002  R051  02-00-00          59 ST      BMT
# ...        ...      ...    ...   ...       ...            ...      ...
# 197620  197620        R  TRAM2  R469  00-05-01  RIT-ROOSEVELT      RIT
# 197621  197621        R  TRAM2  R469  00-05-01  RIT-ROOSEVELT      RIT
# 197622  197622        R  TRAM2  R469  00-05-01  RIT-ROOSEVELT      RIT
# 197623  197623        R  TRAM2  R469  00-05-01  RIT-ROOSEVELT      RIT
# 197624  197624        R  TRAM2  R469  00-05-01  RIT-ROOSEVELT      RIT
#
#              Date      Time     Desc  Entries    Exits  Num_lines day_of_week
# 0      2018-08-25  00:00:00  REGULAR  6736067  2283184          7    Saturday
# 1      2018-08-25  04:00:00  REGULAR  6736087  2283188          7    Saturday
# 2      2018-08-25  08:00:00  REGULAR  6736105  2283229          7    Saturday
# 3      2018-08-25  12:00:00  REGULAR  6736180  2283314          7    Saturday
# 4      2018-08-25  16:00:00  REGULAR  6736349  2283384          7    Saturday
# ...           ...       ...      ...      ...      ...        ...         ...
# 197620 2018-08-31  05:00:00  REGULAR     5554      348          1      Friday
# 197621 2018-08-31  09:00:00  REGULAR     5554      348          1      Friday
# 197622 2018-08-31  13:00:00  REGULAR     5554      348          1      Friday
# 197623 2018-08-31  17:00:00  REGULAR     5554      348          1      Friday
# 197624 2018-08-31  21:00:00  REGULAR     5554      348          1      Friday
#
# [197625 rows x 14 columns]

# %%
# Group the data by day of week and plot the sum of the numeric columns
grouped = df.groupby('day_of_week').sum()
grouped.plot(kind='barh')
plt.show()

# %% [markdown]
# - Remove the index of `grouped`
# - Print the first five rows of `grouped`

# %%
# Reset the index of grouped
grouped.reset_index()

# Print the first five rows of grouped
grouped.head()
# Out:
#   day_of_week       Index        Entries         Exits  Num_lines  is_weekend
# 0      Friday  2778112001  1110224700078  906799065337      75573        True
# 1      Monday  2783610827  1114237052454  911938153513      76110        True
# 2    Saturday  2741377942  1115661545514  909142081474      74725        True
# 3      Sunday  2792287000  1192306179082  959223750461      75306        True
# 4    Thursday  2817391725  1122723988662  920691927110      76607        True

# %% [markdown]
# Add a new column `'is_weekend'` that maps the `'day_of_week'` column using the dictionary `weekend_map`

# %%
# Use this dictionary to create a new column 
weekend_map = {0:False, 1:False, 2:False, 3:False, 4:False, 5:True, 6:True}

# Add a new column 'is_weekend' that maps the 'day_of_week' column using weekend_map
grouped['is_weekend'] = (df['Date'].dt.weekday).map(lambda x: weekend_map[x])

grouped
# Out:
#   day_of_week       Index        Entries         Exits  Num_lines  is_weekend
# 0      Friday  2778112001  1110224700078  906799065337      75573        True
# 1      Monday  2783610827  1114237052454  911938153513      76110        True
# 2    Saturday  2741377942  1115661545514  909142081474      74725        True
# 3      Sunday  2792287000  1192306179082  959223750461      75306        True
# 4    Thursday  2817391725  1122723988662  920691927110      76607        True
# 5     Tuesday  2833413973  1143313287046  942230721477      77303        True
# 6   Wednesday  2781528032  1123655222441  920630864687      75713        True

# %%
# Group the data by weekend/weekday and plot the sum of the numeric columns
wkend = grouped.groupby('is_weekend').mean()
wkend[['Entries', 'Exits']].plot(kind='barh')
plt.show()

# %% [markdown]
# Remove the `'c/a'` and `'scp'` columns.

# %%
# Remove the 'c/a' and 'scp' columns
drop_cols = ['C/a', 'Scp']
grouped
# Out:
#   day_of_week       Index        Entries         Exits  Num_lines  is_weekend
# 0      Friday  2778112001  1110224700078  906799065337      75573        True
# 1      Monday  2783610827  1114237052454  911938153513      76110        True
# 2    Saturday  2741377942  1115661545514  909142081474      74725        True
# 3      Sunday  2792287000  1192306179082  959223750461      75306        True
# 4    Thursday  2817391725  1122723988662  920691927110      76607        True
# 5     Tuesday  2833413973  1143313287046  942230721477      77303        True
# 6   Wednesday  2781528032  1123655222441  920630864687      75713        True

# %% [markdown]
# ## Analysis Question
#
# What is misleading about the day of week and weekend/weekday charts you just plotted?

# %%
More entries than exits

# %% [markdown]
# ## Summary
#
# Great! You practiced your data cleanup skills using Pandas.
